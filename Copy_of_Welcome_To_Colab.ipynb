# %% [markdown]
# <a href="https://colab.research.google.com/github/naveenram123/youthworld/blob/master/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
import os
os.environ["OPENWEATHER_API_KEY"] = "YOUR_REAL_API_KEY"

# %%
import requests
import os

API_KEY = os.getenv("OPENWEATHER_API_KEY")

BASE_URL = "https://api.openweathermap.org/data/2.5/weather"

def get_weather(city):
    if not API_KEY:
        return {"error": "API key not set."}

    params = {
        "q": city,
        "appid": API_KEY,
        "units": "metric"
    }

    try:
        res = requests.get(BASE_URL, params=params, timeout=5)
        res.raise_for_status()
        return res.json()

    except requests.exceptions.HTTPError:
        if res.status_code == 401:
            return {"error": "Invalid API key"}
        elif res.status_code == 404:
            return {"error": "City not found"}
        elif res.status_code == 429:
            return {"error": "Rate limit exceeded"}
        else:
            return {"error": f"HTTP {res.status_code}"}

    except requests.exceptions.RequestException:
        return {"error": "Network issue"}

# %%
data = get_weather("Hyderabad")

print("JSON Output:")
print(data)

if "error" not in data:
    print("\nReadable Output:")
    print("City:", data.get("name"))
    print("Temperature:", data.get("main", {}).get("temp"), "°C")
    print("Weather:", data.get("weather", [{}])[0].get("description"))
# Out:
# JSON Output:
# {'error': 'Invalid API key'}
